# %%
import csv
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

stopwords = [ "a", "about", "above", "after", "again", "against", "all", "am", "an", "and", "any", "are", "as", "at", "be", "because", "been", "before", "being", "below", "between", "both", "but", "by", "could", "did", "do", "does", "doing", "down", "during", "each", "few", "for", "from", "further", "had", "has", "have", "having", "he", "he'd", "he'll", "he's", "her", "here", "here's", "hers", "herself", "him", "himself", "his", "how", "how's", "i", "i'd", "i'll", "i'm", "i've", "if", "in", "into", "is", "it", "it's", "its", "itself", "let's", "me", "more", "most", "my", "myself", "nor", "of", "on", "once", "only", "or", "other", "ought", "our", "ours", "ourselves", "out", "over", "own", "same", "she", "she'd", "she'll", "she's", "should", "so", "some", "such", "than", "that", "that's", "the", "their", "theirs", "them", "themselves", "then", "there", "there's", "these", "they", "they'd", "they'll", "they're", "they've", "this", "those", "through", "to", "too", "under", "until", "up", "very", "was", "we", "we'd", "we'll", "we're", "we've", "were", "what", "what's", "when", "when's", "where", "where's", "which", "while", "who", "who's", "whom", "why", "why's", "with", "would", "you", "you'd", "you'll", "you're", "you've", "your", "yours", "yourself", "yourselves" ]

# %%
sentences = []
labels = []
with open("bbc-text-small.csv", 'r') as csvfile:
    reader = csv.reader(csvfile, delimiter=',')
    next(reader)
    for row in reader:
        labels.append(row[0])
        sentence = row[1]
        for word in stopwords:
            token = " " + word + " "
            sentence = sentence.replace(token, " ")
            sentence = sentence.replace("  ", " ")
        sentences.append(sentence)


print(len(sentences))
print(sentences[48])
print(labels[48])
# Out:
# 49
# libya takes $1bn unfrozen funds libya withdrawn $1bn assets us assets previously frozen almost 20 years libyan central bank said. move came us lifted trade ban reward tripoli giving weapons mass destruction vowing compensate lockerbie victims. original size libya s funds $400m central bank told reuters. however withdrawal not mean libya cut ties us added. process opening accounts banks united states central bank s vice president farhat omar ben gadaravice said. previously frozen assets invested various countries believed included equity holdings banks. us ban trade economic activity tripoli - imposed president ronald regan 1986 series us deemed terrorist acts including 1988 lockerbie air crash - suspended april. bankers two country s working unfreeze libya s assets.
# business

# %%
#oov- out of vocab - replace unknown word with our token
tokenizer = Tokenizer(oov_token="<OOV>")
tokenizer.fit_on_texts(sentences)
index = tokenizer.word_index
print(index)
# Out:
# {'<OOV>': 1, 's': 2, 'said': 3, 'will': 4, 'mr': 5, 'not': 6, 'us': 7, 'one': 8, 'people': 9, 'new': 10, 'can': 11, 'music': 12, 'also': 13, 'year': 14, 'government': 15, 'v': 16, 't': 17, 'now': 18, 'house': 19, 'uk': 20, 'bbc': 21, 'first': 22, 'like': 23, '1': 24, 'china': 25, 'two': 26, 'back': 27, 'film': 28, 'bank': 29, 'show': 30, 'howard': 31, 'get': 32, 'years': 33, 'told': 34, 'last': 35, 'way': 36, 'technology': 37, '000': 38, 'top': 39, 'want': 40, 'number': 41, 'prices': 42, 'tv': 43, 'time': 44, 'help': 45, 'just': 46, 'company': 47, 'three': 48, 'week': 49, 'take': 50, 'used': 51, 'end': 52, 'mobile': 53, 'make': 54, 'going': 55, 'money': 56, 'four': 57, 'election': 58, 'dollar': 59, 'home': 60, 'broadband': 61, 'play': 62, 'party': 63, 'really': 64, 'since': 65, '7': 66, 'set': 67, 'already': 68, 'many': 69, 'made': 70, 'part': 71, 'says': 72, '6': 73, '2': 74, 'around': 75, 'month': 76, 'figures': 77, 'much': 78, 'months': 79, 'no': 80, 'programme': 81, 'put': 82, 'm
# ...

# %%
sequences = tokenizer.texts_to_sequences(sentences)
padd = pad_sequences(sequences,padding='post')
print(padd[0])
print(padd.shape)
# Out:
# [  43  327 1071  563   60 1072 1073 1831   92  426 1074  328  263 1075
#  1076 1077 1832   36    9  214   43    4 1833  564  105   33   44  171
#  1834  752  753  264  265 1835   30 1836 1837  754   10  565    4  427
#     8 1838 1839    7  566  755  756  428    4  757  563  429   60  172
#   758  759  760  173   61  329  567  430 1840 1078 1079    8 1080 1081
#   565 1082  328  761  263 1075  568 1841   67   39 1083   23    7    2
#   762   20    2 1084  431 1085    9  126 1842   62 1086  266 1087   43
#   756   40 1843   37 1088   78 1844   43   13  763 1089   92  426   43
#   569  174  267   93    7 1845   50  175  151 1846   92  426 1847    6
#    11    9  266 1087 1848   11   13 1090 1849   94  432 1091 1092  764
#  1093  433 1850 1094    7  172  758  759  173 1095  268  570 1096 1851
#   106  765 1852 1853 1097 1098  330    7 1854   37  571   13 1855  766
#   151 1099  127 1856  269   23 1084  572  176    4  177 1100   79   33
# ...

# %%
label_tokens = Tokenizer()
label_tokens.fit_on_texts(labels)
print(label_tokens.word_index)
print(label_tokens.texts_to_sequences(labels))
# Out:
# {'tech': 1, 'business': 2, 'sport': 3, 'entertainment': 4, 'politics': 5}
# [[1], [2], [3], [3], [4], [5], [5], [3], [3], [4], [4], [5], [3], [5], [3], [1], [1], [1], [3], [3], [1], [3], [4], [1], [5], [4], [5], [1], [4], [4], [5], [1], [4], [5], [5], [3], [1], [4], [1], [4], [2], [2], [2], [2], [2], [2], [2], [2], [2]]

# %% [markdown]
# **Example-2**

# %%
sentences = [
    'At DDU, we are Learning ML in semester 7 !!!',
    'I love ml subject',
    'Prof Brijesh Bhatt and prof. Hariom Pandya are faculties for the Ml subject',
    'Do you think ML is amazing?'
]

#To lowercase
low_case_sentences = []
for s in sentences:
    low_case_sentences.append(s.lower())
print(low_case_sentences)
# Out:
# ['at ddu, we are learning ml in semester 7 !!!', 'i love ml subject', 'prof brijesh bhatt and prof. hariom pandya are faculties for the ml subject', 'do you think ml is amazing?']

# %%
final_sentences = []
for s in low_case_sentences:
    for word in stopwords:
        token = " " + word + " "
        s = s.replace(token, " ")
        s = s.replace("  ", " ")
    final_sentences.append(s)
print(final_sentences)
# Out:
# ['at ddu, learning ml semester 7 !!!', 'i love ml subject', 'prof brijesh bhatt prof. hariom pandya faculties ml subject', 'do think ml amazing?']

# %%
tokenizer1 = Tokenizer(oov_token="<OOV>")
tokenizer1.fit_on_texts(final_sentences)
word_index = tokenizer1.word_index
print(word_index)
# Out:
# {'<OOV>': 1, 'ml': 2, 'subject': 3, 'prof': 4, 'at': 5, 'ddu': 6, 'learning': 7, 'semester': 8, '7': 9, 'i': 10, 'love': 11, 'brijesh': 12, 'bhatt': 13, 'hariom': 14, 'pandya': 15, 'faculties': 16, 'do': 17, 'think': 18, 'amazing': 19}

# %%
# Padding 
sequences = tokenizer1.texts_to_sequences(final_sentences)
padded = pad_sequences(sequences, padding='post')
print(padded)
print(padded.shape)
# Out:
# [[ 5  6  7  2  8  9  0  0  0]
#  [10 11  2  3  0  0  0  0  0]
#  [ 4 12 13  4 14 15 16  2  3]
#  [17 18  2 19  0  0  0  0  0]]
# (4, 9)
